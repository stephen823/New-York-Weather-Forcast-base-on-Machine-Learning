# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.tools.eval_measures import rmse
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv('Avgtemp.csv')

# %%
df.Month = pd.to_datetime(df.Month)
df = df.set_index("Month")

# %%
train, test = df[:-12], df[-12:]

# %%
scaler = MinMaxScaler()
scaler.fit(train)
train = scaler.transform(train)
test = scaler.transform(test)

# %%
n_input = 12
n_features = 1
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=6)

# %%
model = Sequential()
model.add(LSTM(200, activation='relu', input_shape=(n_input, n_features)))
model.add(Dropout(0.15))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit_generator(generator,epochs=90)
# Out:
# WARNING:tensorflow:From <ipython-input-7-b4e8c6171940>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.1276
# Epoch 2/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0416
# Epoch 3/90
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0110
# Epoch 4/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0175: 0s - loss: 0.017
# Epoch 5/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0090
# Epoch 6/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0085
# Epoch 7/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0072
# Epoch 8/90
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0070
# Epoch 9/90
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0106: 0s - loss:
# Epoch 10/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0079
# Epoch 11/90
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0057
# Epoch 12/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0063
# Epoch 13/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0070
# Epoch 14/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0082
# Epoch 15/90
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0081
# Epoch 16/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0064
# Epoch 17/90
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0073
# Epoch 18/90
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0067
# Epoch 19/90
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0085
# Epoch 20/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0109: 0s - loss: 0.008 - ETA: 0s - loss
# Epoch 21/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0070
# Epoch 22/90
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0067
# Epoch 23/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0051
# Epoch 24/90
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0058
# Epoch 25/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0059
# Epoch 26/90
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0060
# Epoch 27/90
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0060
# Epoch 28/90
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0055
# Epoch 29/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0086
# Epoch 30/90
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0059
# Epoch 31/90
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0064
# Epoch 32/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0064
# Epoch 33/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0056
# Epoch 34/90
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0055
# Epoch 35/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0056
# Epoch 36/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0049
# Epoch 37/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0053
# Epoch 38/90
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0063
# Epoch 39/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0065
# Epoch 40/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0052
# Epoch 41/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0053
# Epoch 42/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0049: 0s - loss:
# Epoch 43/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0046
# Epoch 44/90
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0052
# Epoch 45/90
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0052: 0s - loss
# Epoch 46/90
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0055: 0s - loss: 0.
# Epoch 47/90
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0086: 0s - los
# Epoch 48/90
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0053
# Epoch 49/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0056
# Epoch 50/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0051
# Epoch 51/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0051
# Epoch 52/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0054
# Epoch 53/90
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0047
# Epoch 54/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0067: 0s - loss: 0
# Epoch 55/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0061
# Epoch 56/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0055: 0s - loss: 0
# Epoch 57/90
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0049
# Epoch 58/90
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0054
# Epoch 59/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0054: 0s - loss: 0
# Epoch 60/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0045
# Epoch 61/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0053
# Epoch 62/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0057
# Epoch 63/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0067
# Epoch 64/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0054
# Epoch 65/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0063
# Epoch 66/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0067
# Epoch 67/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0048
# Epoch 68/90
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0052
# Epoch 69/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0063
# Epoch 70/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0050
# Epoch 71/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0045
# Epoch 72/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0055
# Epoch 73/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0058
# Epoch 74/90
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0048
# Epoch 75/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0051
# Epoch 76/90
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0056
# Epoch 77/90
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0048
# Epoch 78/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0056
# Epoch 79/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0056
# Epoch 80/90
# 38/38 [==============================] - 1s 18ms/step - loss: 0.0051
# Epoch 81/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0056
# Epoch 82/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0061
# Epoch 83/90
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0057
# Epoch 84/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0052
# Epoch 85/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0048
# Epoch 86/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0043
# Epoch 87/90
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0049
# Epoch 88/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0039
# Epoch 89/90
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0045
# Epoch 90/90
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0054

# %%
pred_list = []

batch = train[-n_input:].reshape((1, n_input, n_features))

for i in range(n_input):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),
                          index=df[-n_input:].index, columns=['Prediction'])

df_test = pd.concat([df,df_predict], axis=1)

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_test.index, df_test['Avgtemp'])
plt.plot(df_test.index, df_test['Prediction'], color='r')
plt.legend(loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
pred_actual_rmse = rmse(df_test.iloc[-n_input:, [0]], df_test.iloc[-n_input:, [1]])
print("rmse: ", pred_actual_rmse)
# Out:
# rmse:  [1.73711235]

# %%
train = df

# %%
scaler.fit(train)
train = scaler.transform(train)

# %%
n_input = 12
n_features = 1
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=6)

# %%
model.fit_generator(generator,epochs=90)
# Out:
# Epoch 1/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0041
# Epoch 2/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0046
# Epoch 3/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0053
# Epoch 4/90
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0048
# Epoch 5/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0076: 0s - loss:
# Epoch 6/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0044
# Epoch 7/90
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0051
# Epoch 8/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0048
# Epoch 9/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0048
# Epoch 10/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0043
# Epoch 11/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0053: 0s - los
# Epoch 12/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0044
# Epoch 13/90
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0043
# Epoch 14/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0046
# Epoch 15/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0044
# Epoch 16/90
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0044
# Epoch 17/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0045
# Epoch 18/90
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0053
# Epoch 19/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0040
# Epoch 20/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0042
# Epoch 21/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0041: 0s - los
# Epoch 22/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0042
# Epoch 23/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0041
# Epoch 24/90
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0046
# Epoch 25/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0050
# Epoch 26/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0049
# Epoch 27/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0042
# Epoch 28/90
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0052
# Epoch 29/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0057
# Epoch 30/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0053
# Epoch 31/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0047: 0s - loss:
# Epoch 32/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0041
# Epoch 33/90
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0044
# Epoch 34/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0041
# Epoch 35/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0041
# Epoch 36/90
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0043
# Epoch 37/90
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0049
# Epoch 38/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0042
# Epoch 39/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0037
# Epoch 40/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0042
# Epoch 41/90
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0041
# Epoch 42/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0049
# Epoch 43/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0041
# Epoch 44/90
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0043: 0s - loss
# Epoch 45/90
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0045
# Epoch 46/90
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0040
# Epoch 47/90
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0043
# Epoch 48/90
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0050
# Epoch 49/90
# 40/40 [==============================] - 1s 22ms/step - loss: 0.0045
# Epoch 50/90
# 40/40 [==============================] - 1s 21ms/step - loss: 0.0045: 0s - loss: 0.00
# Epoch 51/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0039: 0s - loss
# Epoch 52/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0045
# Epoch 53/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0047
# Epoch 54/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0042
# Epoch 55/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0048
# Epoch 56/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0042
# Epoch 57/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0044
# Epoch 58/90
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0040
# Epoch 59/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0041
# Epoch 60/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0039
# Epoch 61/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0041
# Epoch 62/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0042
# Epoch 63/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0042
# Epoch 64/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0049
# Epoch 65/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0038
# Epoch 66/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0039
# Epoch 67/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0041
# Epoch 68/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0040
# Epoch 69/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0044
# Epoch 70/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0042
# Epoch 71/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0042
# Epoch 72/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0037
# Epoch 73/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0045: 0s - loss: 0.0
# Epoch 74/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0041
# Epoch 75/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0038
# Epoch 76/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0038
# Epoch 77/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0041
# Epoch 78/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0043
# Epoch 79/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0046
# Epoch 80/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0048
# Epoch 81/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0040
# Epoch 82/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0041
# Epoch 83/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0043
# Epoch 84/90
# 40/40 [==============================] - 1s 17ms/step - loss: 0.0044
# Epoch 85/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0039
# Epoch 86/90
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0039: 0s - loss: 0.0
# Epoch 87/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0036
# Epoch 88/90
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0040
# Epoch 89/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0046
# Epoch 90/90
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0040

# %%
pred_list = []

batch = train[-n_input:].reshape((1, n_input, n_features))

for i in range(n_input):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
from pandas.tseries.offsets import DateOffset
add_dates = [df.index[-1] + DateOffset(months=x) for x in range(0,13) ]
future_dates = pd.DataFrame(index=add_dates[1:],columns=df.columns)

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),
                          index=future_dates[-n_input:].index, columns=['Prediction'])

df_proj = pd.concat([df,df_predict], axis=1)

# %%
plt.figure(figsize=(20, 5))
plt.plot(df_proj.index, df_proj['Avgtemp'])
plt.plot(df_proj.index, df_proj['Prediction'], color='r')
plt.legend(loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()
# Out:
# No handles with labels found to put in legend.
